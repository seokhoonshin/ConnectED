# %%
pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (3.5.2)
# Requirement already satisfied: seaborn in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pandas>=0.23 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: scipy>=1.0 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/jasonshin/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

file_path = 'exported_data.xlsx'
elements_df = pd.read_excel(file_path, header=1)

elements_df['Last Date'] = pd.to_datetime(elements_df['Last Date'], errors='coerce')

elements_2024_last_date_df = elements_df[elements_df['Last Date'].dt.year == 2024]

print("Filtered Elements with Last Date 2024:")
print(elements_2024_last_date_df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Last Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_29049/4138614365.py in <module>
#       4 elements_df = pd.read_excel(file_path, header=1)
#       5
# ----> 6 elements_df['Last Date'] = pd.to_datetime(elements_df['Last Date'], errors='coerce')
#       7
#       8 elements_2024_last_date_df = elements_df[elements_df['Last Date'].dt.year == 2024]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Last Date'

# %%
unique_races = elements_2024_df['What is your race/ethnicity?'].unique()
print(unique_races)
# Out:
# ['White' 'Two or More Races' 'Hispanic/Latino' 'Asian' 'Middle Eastern'
#  'Native Hawaiian/Pacific Islander']

# %%
race_mapping = {
    # White
    'Caucasian': 'White',
    'European': 'White',
    'Anglo': 'White',
    'White': 'White',
    
    # Hispanic/Latino
    'Hispanic': 'Hispanic/Latino',
    'Latino': 'Hispanic/Latino',
    'Latina': 'Hispanic/Latino',
    'Hispanic/Latino': 'Hispanic/Latino',
    'Mexican': 'Hispanic/Latino',
    'Chicano': 'Hispanic/Latino',
    
    # Two or More Races
    'Two or More Races': 'Two or More Races',
    'Mixed Race': 'Two or More Races',
    
    # American Indian/Alaskan Native
    'American Indian': 'American Indian/Alaskan Native',
    'Native American': 'American Indian/Alaskan Native',
    'Alaskan Native': 'American Indian/Alaskan Native',
    
    # Asian
    'Asian': 'Asian',
    'Asian American': 'Asian',
    'East Asian': 'Asian',
    'South Asian': 'Asian',
    'Southeast Asian': 'Asian',
    
    # Native Hawaiian/Pacific Islander
    'Native Hawaiian': 'Native Hawaiian/Pacific Islander',
    'Pacific Islander': 'Native Hawaiian/Pacific Islander',
    'Polynesian': 'Native Hawaiian/Pacific Islander',
    'Micronesian': 'Native Hawaiian/Pacific Islander',
    'Melanesian': 'Native Hawaiian/Pacific Islander',
    
    # Middle Eastern
    'Middle Eastern': 'Middle Eastern',
    'Arab': 'Middle Eastern',
    'Persian': 'Middle Eastern',
    'Turkish': 'Middle Eastern',
    'North African': 'Middle Eastern',

    # Additional categories (optional)
    'Black': 'Black/African American',  
    'African American': 'Black/African American',  
    'Afro-American': 'Black/African American', 
}


elements_2024_df['What is your race/ethnicity?'] = elements_2024_df['What is your race/ethnicity?'].replace(race_mapping)

elements_2024_df = elements_2024_df[
    elements_2024_df['What is your race/ethnicity?'].isin([
        'White', 
        'Hispanic/Latino', 
        'Two or More Races', 
        'American Indian/Alaskan Native', 
        'Asian', 
        'Native Hawaiian/Pacific Islander', 
        'Middle Eastern'
    ])
]

unique_races_consolidated = elements_2024_df['What is your race/ethnicity?'].unique()
print(unique_races_consolidated)
# Out:
# ['White' 'Two or More Races' 'Hispanic/Latino' 'Asian' 'Middle Eastern'
#  'Native Hawaiian/Pacific Islander']

# %%
race_mapping = {
    'Caucasian': 'White',
    'European': 'White',
    'Anglo': 'White',
    'White': 'White',
    'Hispanic': 'Hispanic/Latino',
    'Latino': 'Hispanic/Latino',
    'Latina': 'Hispanic/Latino',
    'Hispanic/Latino': 'Hispanic/Latino',
    'Mexican': 'Hispanic/Latino',
    'Chicano': 'Hispanic/Latino',
    'Two or More Races': 'Two or More Races',
    'Mixed Race': 'Two or More Races',
    'American Indian': 'American Indian/Alaskan Native',
    'Native American': 'American Indian/Alaskan Native',
    'Alaskan Native': 'American Indian/Alaskan Native',
    'Asian': 'Asian',
    'Asian American': 'Asian',
    'East Asian': 'Asian',
    'South Asian': 'Asian',
    'Southeast Asian': 'Asian',
    'Native Hawaiian': 'Native Hawaiian/Pacific Islander',
    'Pacific Islander': 'Native Hawaiian/Pacific Islander',
    'Polynesian': 'Native Hawaiian/Pacific Islander',
    'Micronesian': 'Native Hawaiian/Pacific Islander',
    'Melanesian': 'Native Hawaiian/Pacific Islander',
    'Middle Eastern': 'Middle Eastern',
    'Arab': 'Middle Eastern',
    'Persian': 'Middle Eastern',
    'Turkish': 'Middle Eastern',
    'North African': 'Middle Eastern',
}

elements_2024_df['What is your race/ethnicity?'] = elements_2024_df['What is your race/ethnicity?'].replace(race_mapping)

elements_2024_df = elements_2024_df[
    elements_2024_df['What is your race/ethnicity?'].isin([
        'White', 
        'Hispanic/Latino', 
        'Two or More Races', 
        'American Indian/Alaskan Native', 
        'Asian', 
        'Native Hawaiian/Pacific Islander', 
        'Middle Eastern'
    ])
]

race_counts = elements_2024_df['What is your race/ethnicity?'].value_counts()
total_students = race_counts.sum()
race_percentage = (race_counts / total_students) * 100

# Plot
plt.figure(figsize=(10, 6))
race_percentage.plot(kind='bar', color='skyblue')
plt.title('Distribution of Students by Race (Population Percentage)')
plt.xlabel('Race/Ethnicity')
plt.ylabel('Percentage of Students (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_70894/14297785.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['What is your race/ethnicity?'] = elements_2024_df['What is your race/ethnicity?'].replace(race_mapping)

# %%
elements_df['Last Date'] = pd.to_datetime(elements_df['Last Date'], errors='coerce')

elements_2024_df = elements_df[elements_df['Last Date'].dt.year == 2024]

elements_2024_df['What is your gender?'] = elements_2024_df['What is your gender?'].astype(str)

gender_counts = elements_2024_df['What is your gender?'].value_counts()
total_students = gender_counts.sum()
gender_percentage = (gender_counts / total_students) * 100

plt.figure(figsize=(10, 6))
gender_percentage.plot(kind='bar', color='lightcoral')
plt.title('Distribution of Students by Gender (Population Percentage)')
plt.xlabel('Gender')
plt.ylabel('Percentage of Students (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_70894/1032400320.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['What is your gender?'] = elements_2024_df['What is your gender?'].astype(str)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = '10:10:24 PC Elements.xlsx'
elements_df = pd.read_excel(file_path, header=1)

elements_df['Last Date'] = pd.to_datetime(elements_df['Last Date'], errors='coerce')

elements_2024_df = elements_df[elements_df['Last Date'].dt.year == 2024]

race_mapping = {
    # White
    'Caucasian': 'White',
    'European': 'White',
    'Anglo': 'White',
    'White': 'White',
    
    # Hispanic/Latino
    'Hispanic': 'Hispanic/Latino',
    'Latino': 'Hispanic/Latino',
    'Latina': 'Hispanic/Latino',
    'Hispanic/Latino': 'Hispanic/Latino',
    'Mexican': 'Hispanic/Latino',
    'Chicano': 'Hispanic/Latino',
    
    # Two or More Races
    'Two or More Races': 'Two or More Races',
    'Mixed Race': 'Two or More Races',
    
    # American Indian/Alaskan Native
    'American Indian': 'American Indian/Alaskan Native',
    'Native American': 'American Indian/Alaskan Native',
    'Alaskan Native': 'American Indian/Alaskan Native',
    
    # Asian
    'Asian': 'Asian',
    'Asian American': 'Asian',
    'East Asian': 'Asian',
    'South Asian': 'Asian',
    'Southeast Asian': 'Asian',
    
    # Native Hawaiian/Pacific Islander
    'Native Hawaiian': 'Native Hawaiian/Pacific Islander',
    'Pacific Islander': 'Native Hawaiian/Pacific Islander',
    'Polynesian': 'Native Hawaiian/Pacific Islander',
    'Micronesian': 'Native Hawaiian/Pacific Islander',
    'Melanesian': 'Native Hawaiian/Pacific Islander',
    
    # Middle Eastern
    'Middle Eastern': 'Middle Eastern',
    'Arab': 'Middle Eastern',
    'Persian': 'Middle Eastern',
    'Turkish': 'Middle Eastern',
    'North African': 'Middle Eastern',
}

elements_2024_df['What is your race/ethnicity?'] = elements_2024_df['What is your race/ethnicity?'].replace(race_mapping)

elements_2024_df = elements_2024_df[
    elements_2024_df['What is your race/ethnicity?'].isin([
        'White', 
        'Hispanic/Latino', 
        'Two or More Races', 
        'American Indian/Alaskan Native', 
        'Asian', 
        'Native Hawaiian/Pacific Islander', 
        'Middle Eastern'
    ])
]

elements_2024_df['Belonging Barometer Number'] = pd.to_numeric(elements_2024_df['Belonging Barometer Number'], errors='coerce')
elements_2024_df['The school community you are a part of.'] = elements_2024_df['The school community you are a part of.'].astype(str)
elements_2024_df['What is your gender?'] = elements_2024_df['What is your gender?'].astype(str)

plt.figure(figsize=(12, 6))
sns.boxplot(x='What is your race/ethnicity?', y='Belonging Barometer Number', data=elements_2024_df)
plt.title('Sense of Belonging by Race')
plt.xlabel('Race/Ethnicity')
plt.ylabel('Belonging Barometer Number')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='What is your gender?', y='Belonging Barometer Number', data=elements_2024_df)
plt.title('Sense of Belonging by Gender')
plt.xlabel('Gender')
plt.ylabel('Belonging Barometer Number')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_70894/581889642.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['What is your race/ethnicity?'] = elements_2024_df['What is your race/ethnicity?'].replace(race_mapping)

# %% [markdown]
# In the box plot, we see that for the White group, which has the most distribution among the all races, there are several outliers on the lower end. And i thought that this suggests that while many White students report a moderate sense of belonging, there are individuals who feel disconnected or unsupported.
#
# On the other hand, we might also find outliers at the higher end of the score range. These students may have exceptionally positive experiences that could serve as models for others. Understanding what contributes to their strong sense of belonging could help us enhance our support for other students.
#
# Need for Further Exploration: I will further focus on the ouliers that has low belonging scores and will try to make relationships with other categorical sense of belonging questions or activity involvement.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = '10:10:24 PC Elements.xlsx'
elements_df = pd.read_excel(file_path, header=1)

# Convert 'Last Date' to datetime format
elements_df['Last Date'] = pd.to_datetime(elements_df['Last Date'], errors='coerce')

# Filter for entries from the year 2024
elements_2024_df = elements_df[elements_df['Last Date'].dt.year == 2024]

# Convert relevant columns to appropriate types
elements_2024_df['Belonging Barometer Number'] = pd.to_numeric(elements_2024_df['Belonging Barometer Number'], errors='coerce')
elements_2024_df['The school community you are a part of.'] = elements_2024_df['The school community you are a part of.'].astype(str)

# Visualization: Box Plot for Sense of Belonging by School Community
plt.figure(figsize=(12, 6))
sns.boxplot(x='The school community you are a part of.', y='Belonging Barometer Number', data=elements_2024_df)
plt.title('Sense of Belonging by School Level')
plt.xlabel('School Community (High School / Middle School)')
plt.ylabel('Belonging Barometer Number')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_79665/3259957365.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['Belonging Barometer Number'] = pd.to_numeric(elements_2024_df['Belonging Barometer Number'], errors='coerce')
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_79665/3259957365.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['The school community you are a part of.'] = elements_2024_df['The school community you are a part of.'].astype(str)

# %%
import pandas as pd

# Load the dataset
file_path = '10:10:24 PC Elements.xlsx'
elements_df = pd.read_excel(file_path, header=1)

# Function to categorize time spent online
def categorize_online_time(time_spent):
    if pd.isnull(time_spent):
        return 'No response'
    elif 'less than an hour' in time_spent:
        return 'Less than 1 hour'
    elif '1 - 3 hours' in time_spent:
        return '1 - 3 hours'
    elif '4 - 6 hours' in time_spent:
        return '4 - 6 hours'
    elif '7 - 9 hours' in time_spent:
        return '7 - 9 hours'
    elif 'more than 9 hours' in time_spent:
        return 'More than 9 hours'
    else:
        return 'Other'  # Catch-all for unexpected values

# Apply the categorization function to the column
elements_df['Online Time Category'] = elements_df['How much time do you spend online?'].apply(categorize_online_time)

# Display the updated DataFrame to check the new category
print(elements_df[['How much time do you spend online?', 'Online Time Category']].head(10))
# Out:
#   How much time do you spend online? Online Time Category
# 0                  1 - 3 hours a day          1 - 3 hours
# 1                  1 - 3 hours a day          1 - 3 hours
# 2                  4 - 6 hours a day          4 - 6 hours
# 3                                NaN          No response
# 4                  4 - 6 hours a day          4 - 6 hours
# 5                                NaN          No response
# 6                  1 - 3 hours a day          1 - 3 hours
# 7                                NaN          No response
# 8                  4 - 6 hours a day          4 - 6 hours
# 9                  4 - 6 hours a day          4 - 6 hours

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = '10:10:24 PC Elements.xlsx'
elements_df = pd.read_excel(file_path, header=1)

# Convert 'Last Date' to datetime format
elements_df['Last Date'] = pd.to_datetime(elements_df['Last Date'], errors='coerce')

# Filter for entries from the year 2024
elements_2024_df = elements_df[elements_df['Last Date'].dt.year == 2024]

# Function to categorize time spent online
def categorize_online_time(time_spent):
    if pd.isnull(time_spent):
        return 'No response'
    elif 'less than an hour' in time_spent:
        return 'Less than 1 hour'
    elif '1 - 3 hours' in time_spent:
        return '1 - 3 hours'
    elif '4 - 6 hours' in time_spent:
        return '4 - 6 hours'
    elif '7 - 9 hours' in time_spent:
        return '7 - 9 hours'
    elif 'more than 9 hours' in time_spent:
        return 'More than 9 hours'
    else:
        return 'Other'  # Catch-all for unexpected values

# Apply the categorization function to the column
elements_2024_df['Online Time Category'] = elements_2024_df['How much time do you spend online?'].apply(categorize_online_time)

# Convert sense of belonging score to numeric
elements_2024_df['Belonging Barometer Number'] = pd.to_numeric(elements_2024_df['Belonging Barometer Number'], errors='coerce')

# Create a box plot to visualize the correlation
plt.figure(figsize=(12, 6))
sns.boxplot(x='Online Time Category', y='Belonging Barometer Number', data=elements_2024_df, palette='coolwarm')
plt.title('Sense of Belonging by Time Spent Online')
plt.xlabel('Online Time Category')
plt.ylabel('Belonging Barometer Number')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_79665/3221488024.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['Online Time Category'] = elements_2024_df['How much time do you spend online?'].apply(categorize_online_time)
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_79665/3221488024.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['Belonging Barometer Number'] = pd.to_numeric(elements_2024_df['Belonging Barometer Number'], errors='coerce')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = '10:10:24 PC Elements.xlsx'
elements_df = pd.read_excel(file_path, header=1)

# Convert 'Last Date' to datetime format
elements_df['Last Date'] = pd.to_datetime(elements_df['Last Date'], errors='coerce')

# Filter for entries from the year 2024
elements_2024_df = elements_df[elements_df['Last Date'].dt.year == 2024]

# Function to categorize time spent online
def categorize_online_time(time_spent):
    if pd.isnull(time_spent):
        return 'No response'
    elif 'less than an hour' in time_spent:
        return 'Less than 1 hour'
    elif '1 - 3 hours' in time_spent:
        return '1 - 3 hours'
    elif '4 - 6 hours' in time_spent:
        return '4 - 6 hours'
    elif '7 - 9 hours' in time_spent:
        return '7 - 9 hours'
    elif 'more than 9 hours' in time_spent:
        return 'More than 9 hours'
    else:
        return 'Other'  # Catch-all for unexpected values

# Apply the categorization function to the column
elements_2024_df['Online Time Category'] = elements_2024_df['How much time do you spend online?'].apply(categorize_online_time)

# Convert sense of belonging score to numeric
elements_2024_df['Belonging Barometer Number'] = pd.to_numeric(elements_2024_df['Belonging Barometer Number'], errors='coerce')

# Calculate the average sense of belonging score for each online time category
average_belonging = elements_2024_df.groupby('Online Time Category')['Belonging Barometer Number'].mean().reset_index()

# Plotting the average sense of belonging by online time category
plt.figure(figsize=(12, 6))
sns.barplot(x='Online Time Category', y='Belonging Barometer Number', data=average_belonging, palette='viridis')
plt.title('Average Sense of Belonging by Time Spent Online')
plt.xlabel('Online Time Category')
plt.ylabel('Average Belonging Barometer Number')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_79665/926762320.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['Online Time Category'] = elements_2024_df['How much time do you spend online?'].apply(categorize_online_time)
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_79665/926762320.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['Belonging Barometer Number'] = pd.to_numeric(elements_2024_df['Belonging Barometer Number'], errors='coerce')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = '10:10:24 PC Elements.xlsx'
elements_df = pd.read_excel(file_path, header=1)

# Convert 'Last Date' to datetime format
elements_df['Last Date'] = pd.to_datetime(elements_df['Last Date'], errors='coerce')

# Filter for entries from the year 2024
elements_2024_df = elements_df[elements_df['Last Date'].dt.year == 2024]

# Function to categorize time spent online
def categorize_online_time(time_spent):
    if pd.isnull(time_spent):
        return 'No response'
    elif 'less than an hour' in time_spent:
        return 'Less than 1 hour'
    elif '1 - 3 hours' in time_spent:
        return '1 - 3 hours'
    elif '4 - 6 hours' in time_spent:
        return '4 - 6 hours'
    elif '7 - 9 hours' in time_spent:
        return '7 - 9 hours'
    elif 'more than 9 hours' in time_spent:
        return 'More than 9 hours'
    else:
        return 'Other'  # Catch-all for unexpected values

# Apply the categorization function to the column
elements_2024_df['Online Time Category'] = elements_2024_df['How much time do you spend online?'].apply(categorize_online_time)

# Convert sense of belonging score to numeric
elements_2024_df['Belonging Barometer Number'] = pd.to_numeric(elements_2024_df['Belonging Barometer Number'], errors='coerce')

# Calculate the average sense of belonging score for each online time category
average_belonging = elements_2024_df.groupby('Online Time Category')['Belonging Barometer Number'].mean().reset_index()

# Define the order of the categories for plotting
category_order = [
    'Less than 1 hour',
    '1 - 3 hours',
    '4 - 6 hours',
    '7 - 9 hours',
    'More than 9 hours',
    'No response'
]

# Plotting the average sense of belonging by online time category
plt.figure(figsize=(12, 6))
sns.barplot(x='Online Time Category', y='Belonging Barometer Number', data=average_belonging, palette='viridis', order=category_order)
plt.title('Average Sense of Belonging by Time Spent Online (0 to 5 scale)')
plt.xlabel('Online Time Category')
plt.ylabel('Average Belonging Barometer Number')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_79665/1435703574.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['Online Time Category'] = elements_2024_df['How much time do you spend online?'].apply(categorize_online_time)
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_79665/1435703574.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['Belonging Barometer Number'] = pd.to_numeric(elements_2024_df['Belonging Barometer Number'], errors='coerce')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# Load the dataset
file_path = '10:10:24 PC Elements.xlsx'
elements_df = pd.read_excel(file_path, header=1)

# Convert 'Last Date' to datetime format
elements_df['Last Date'] = pd.to_datetime(elements_df['Last Date'], errors='coerce')

# Filter for entries from the year 2024
elements_2024_df = elements_df[elements_df['Last Date'].dt.year == 2024]

# Function to categorize time spent online
def categorize_online_time(time_spent):
    if pd.isnull(time_spent):
        return 'No response'
    elif 'less than an hour' in time_spent:
        return 'Less than 1 hour'
    elif '1 - 3 hours' in time_spent:
        return '1 - 3 hours'
    elif '4 - 6 hours' in time_spent:
        return '4 - 6 hours'
    elif '7 - 9 hours' in time_spent:
        return '7 - 9 hours'
    elif 'more than 9 hours' in time_spent:
        return 'More than 9 hours'
    else:
        return 'Other'  # Catch-all for unexpected values

# Apply the categorization function to the column
elements_2024_df['Online Time Category'] = elements_2024_df['How much time do you spend online?'].apply(categorize_online_time)

# Convert sense of belonging score to numeric
elements_2024_df['Belonging Barometer Number'] = pd.to_numeric(elements_2024_df['Belonging Barometer Number'], errors='coerce')

# Calculate the average sense of belonging score for each online time category
average_belonging = elements_2024_df.groupby('Online Time Category')['Belonging Barometer Number'].mean().reset_index()

# Apply z-score normalization to the average scores
average_belonging['Z-Score'] = zscore(average_belonging['Belonging Barometer Number'])

# Define the order of the categories
category_order = [
    'Less than 1 hour',
    '1 - 3 hours',
    '4 - 6 hours',
    '7 - 9 hours',
    'More than 9 hours',
    'No response'
]

# Plotting the z-score average sense of belonging by online time category with specified order
plt.figure(figsize=(12, 6))
sns.barplot(x='Online Time Category', y='Z-Score', data=average_belonging, palette='viridis', order=category_order)
plt.title('Z-Score Normalized Average Sense of Belonging by Time Spent Online')
plt.xlabel('Online Time Category')
plt.ylabel('Z-Score of Average Belonging Barometer Number')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_79665/289583467.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['Online Time Category'] = elements_2024_df['How much time do you spend online?'].apply(categorize_online_time)
# /var/folders/9t/7rt0m2d561d_bf1kjzfvybkw0000gn/T/ipykernel_79665/289583467.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements_2024_df['Belonging Barometer Number'] = pd.to_numeric(elements_2024_df['Belonging Barometer Number'], errors='coerce')
